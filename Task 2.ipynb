# %% [markdown]
# DATA SCIENCE
# TASK 2:Perform data cleaning and exploratory data analysis (EDA) on a dataset of your choice, such as the Titanic dataset from Kaggle. Explore the relationships between variables and identify patterns and trends in the data.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data=pd.read_csv('C:/Users/dheer/Downloads/train.csv')
data.head() #first 5 data
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
data.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
data.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 637          638         0       2
# 459          460         0       3
# 587          588         1       1
# 715          716         0       3
# 552          553         0       3
#
#                                            Name   Sex   Age  SibSp  Parch  \
# 637                         Collyer, Mr. Harvey  male  31.0      1      1
# 459                       O'Connor, Mr. Maurice  male   NaN      0      0
# 587            Frolicher-Stehli, Mr. Maxmillian  male  60.0      1      1
# 715  Soholt, Mr. Peter Andreas Lauritz Andersen  male  19.0      0      0
# 552                        O'Brien, Mr. Timothy  male   NaN      0      0
#
#          Ticket     Fare  Cabin Embarked
# 637  C.A. 31921  26.2500    NaN        S
# 459      371060   7.7500    NaN        Q
# 587       13567  79.2000    B41        C
# 715      348124   7.6500  F G73        S
# 552      330979   7.8292    NaN        Q

# %%
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# Data Cleaning

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
#Fill missing values for Age with median
data['Age'].fillna(data['Age'].median(),inplace=True)

#dropping the column cabin due to high missing value
data.drop('Cabin',axis=1,inplace=True)

#fill missing value for Embarked with mode
data['Embarked'].fillna(data['Embarked'].mode()[0],inplace=True)
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %% [markdown]
# Exploratory Data Analysis (EDA)

# %%
sns.barplot(x='Sex', y='Survived', data=data, ci=None)
plt.title('Survival Rate by Gender')
plt.show()
# Out:
# C:\Users\dheer\AppData\Local\Temp\ipykernel_24816\2192724839.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Sex', y='Survived', data=data, ci=None)

# %%
sns.barplot(x='Pclass', y='Survived', data=data, ci=None)
plt.title('Survival Rate by Passenger Class')
plt.show()
# Out:
# C:\Users\dheer\AppData\Local\Temp\ipykernel_24816\3462479193.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='Pclass', y='Survived', data=data, ci=None)

# %%
sns.histplot(data['Age'], bins=20, kde=True)
plt.title('Distribution of Age')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.histplot(data=data,x='Age',hue='Pclass',kde=True)
plt.show()

# %%
plt.figure(figsize=(15,10))
sns.histplot(data=data,x='Age',hue='Survived',kde=True)
plt.title('Survived age of passenger')
plt.show()

# %%
sns.scatterplot(x='Age', y='Fare', hue='Survived', data=data)
plt.title('Relationship between Age, Fare, and Survival')
plt.show()

# %%
# Drop non-numeric columns and calculating correlation
numeric_data = data.drop(['Name', 'Ticket', 'Embarked','Sex'], axis=1).corr()
# Plot heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_data, annot=True, cmap='inferno', fmt='.2f', linewidths=0.5)
plt.title('Correlation Matrix')
plt.show()
